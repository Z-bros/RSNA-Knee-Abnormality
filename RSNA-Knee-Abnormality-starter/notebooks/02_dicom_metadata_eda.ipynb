# %% [markdown]
# # 02 Dicom Metadata Eda
#
# Work through the questions below after attaching the competition dataset. Keep observations alongside plots and tables.

# %% [markdown]
# ## Goal: learn what one DICOM series contains
#
# Notes / findings:

# %% [markdown]
# ## Select one study and list its DICOM files
#
# Notes / findings:

# %% [markdown]
# ## Read headers without pixels using pydicom
#
# Notes / findings:

# %% [markdown]
# ## Inspect StudyInstanceUID, SeriesInstanceUID, orientation, position, spacing and dimensions
#
# Notes / findings:

# %% [markdown]
# ## Compare metadata across the study and record anomalies
#
# Notes / findings:

# %%
from pathlib import Path
import pandas as pd
import pydicom
import matplotlib.pyplot as plt

# Set this to the mounted Kaggle competition directory.
DATA_ROOT = Path("/kaggle/input/rsna-knee-abnormality-detection")
print("Dataset path exists:", DATA_ROOT.exists())
