# %% [markdown]
# # 03 Mri Visualization
#
# Work through the questions below after attaching the competition dataset. Keep observations alongside plots and tables.

# %% [markdown]
# ## Goal: understand slices, series, and anatomy
#
# Notes / findings:

# %% [markdown]
# ## Load pixels for one selected series
#
# Notes / findings:

# %% [markdown]
# ## Check spatial metadata and order slices geometrically where valid
#
# Notes / findings:

# %% [markdown]
# ## Display representative slices and an intensity histogram
#
# Notes / findings:

# %% [markdown]
# ## Compare series and record artifacts or unusual orientations
#
# Notes / findings:

# %%
from pathlib import Path
import pandas as pd
import pydicom
import matplotlib.pyplot as plt

# Set this to the mounted Kaggle competition directory.
DATA_ROOT = Path("/kaggle/input/rsna-knee-abnormality-detection")
print("Dataset path exists:", DATA_ROOT.exists())
