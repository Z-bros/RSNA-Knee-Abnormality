# %% [markdown]
# # 01 Dataset Overview
#
# Work through the questions below after attaching the competition dataset. Keep observations alongside plots and tables.

# %% [markdown]
# ## Goal: map the provided tables and study identifiers
#
# Notes / findings:

# %% [markdown]
# ## Locate CSV files and inspect their columns
#
# Notes / findings:

# %% [markdown]
# ## Count studies, series, label availability, and missing values
#
# Notes / findings:

# %% [markdown]
# ## Explore label frequencies and series per study
#
# Notes / findings:

# %% [markdown]
# ## Record observations and open questions
#
# Notes / findings:

# %%
from pathlib import Path
import pandas as pd
import pydicom
import matplotlib.pyplot as plt

# Set this to the mounted Kaggle competition directory.
DATA_ROOT = Path("/kaggle/input/rsna-knee-abnormality-detection")
print("Dataset path exists:", DATA_ROOT.exists())
